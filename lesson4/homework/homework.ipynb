# %% [markdown]
# # Задание 1
#
# В чем принципиальное отличие гибридных рекомендательных систем от коллаборативной фильтрации?

# %% [markdown]
# Гибридные рекомендательные системы используют дополнительную информацию о пользователях/товарах из других систем.
# Больше фич = больше знаний = потенциально более сложные и точные модели на выходе. Цена вопроса - скорость обучения модели.

# %% [markdown]
# Приведите 2-3 примера задач, в которых необходимо использовать гибридные системы

# %% [markdown]
# В принципе везде, где применяются системы с коллаборативной фильтрацией, можно применять и гибридные системы, просто в гибридных будут применяться данные с большим количеством фич.
# Тот же онлайн кинотеатр, в котором используются данные о пользователях из каких-нибудь соцсетей
# Ну или магазин компьютерных игр, в котором так же используются данные онлайн кинотеатра.

# %% [markdown]
# Прочитайте статью про поиск на hh.ru https://habr.com/ru/company/hh/blog/347276/
# Нам интересна именно рекомендательная система, раздел "Производительность системы" можно пропустить
# Какие основные отличия предложенной системы от тех подходов, которые мы разбирали на семинарах? Какие проблемы могут возникнуть при выводе такой модели в продакшен?

# %% [markdown]
# Их модель каскадная. У нас нет.
# Их модель требует дополнительного ранжирования в другой системе (а если там алгоритм ранжирования изменится, не очень понятно, как будет работать каскад)

# %% [markdown]
# # Задание 2
#
# На вебинаре мы рассматривали модель LightFM (https://making.lyst.com/lightfm/docs/lightfm.html). В работе Data Scientist'а важную часть занимает research -
# исследование существующих архитектур и разбор научных статей, в которых они описываются.
# Вам предлагается изчуть оригинальную статью про LightFM https://arxiv.org/pdf/1507.08439.pdf и ответить на следующие вопросы:
# - Какой датасет используют авторы?
# - Что используют в качестве признаков?
# - С какими моделями сравнивают LightFM? Опишите их основные идеи кратко

# %% [markdown]
# Ответ 1:
# 1. MovieLens - большой датасет с данными об истории взаимодействий пользователей с фильмами.
# 2. CrossValidated - меньшего размера датасет с разреженными данными о пользовательских вопросах и ответах на них
#
# Ответ2:
# MovieLens - жанры, тэги, рейтинг тега, оценки пользователей
# CrossValidated - вопросы пользователей и ответы на них
#
# Ответ3:
# Сollaborative MF - Обычная матричная модель факторизации со смещениями пользователей и элементов и функцией сигмовидной связи ("a conventional matrix factorisation model with user and item biases and a sigmoid link function")
#
# LSI-LR - Content-Based модель с логистической регрессией для каждого пользователя. Основывается на факторизации матрицы контента ("based on factorising the content matrix").
#
# LSI-UP - Гибридная модель, представляющая профили пользователей (UP) в виде линейных комбинаций векторов содержимого элементов ("a hybrid model that represents user profiles
# (UP) as linear combinations of items’ content vectors")
